# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulpathakmit/capstone/blob/master/image_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **FACE DETECTION**

# %%
pip install face-recognition

# %%
import face_recognition as fr
import dlib
import cv2

# %%
from google.colab import files

# %%
image=files.upload()
# Out:
#      <input type="file" id="files-c5fffb9c-dbdb-4744-b0d1-4df5717a4f3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5fffb9c-dbdb-4744-b0d1-4df5717a4f3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving virat_dhoni.jpeg to virat_dhoni.jpeg

# %%
import io
from skimage import io as I
from google.colab.patches import cv2_imshow

# %%
sample=I.imread(io.BytesIO(image['virat.jpg']))

# %%
cv2_imshow(sample)
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F9F3A359C18>

# %%
locations=fr.face_locations(sample)

# %%
for face in locations:
	  cv2.rectangle(sample,(face[3],face[0]),(face[1],face[2]),(0,255,0),2)

# %%
print(locations)
# Out:
# [(56, 165, 146, 76)]

# %%
cv2_imshow(sample)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F9F39A507F0>
# -1

# %%
current_img = cv2.imread('virat.jpg')
cv2.imwrite('virat.jpg', current_img)
# Out:
# True

# %%
cv2_imshow(current_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F9F39A50D30>
# -1

# %%
locations=fr.face_locations(current_img)

# %%
for face in locations:
	  cv2.rectangle(current_img,(face[3],face[0]),(face[1],face[2]),(0,255,0),2)

# %%
cv2_imshow(current_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=260x260 at 0x7F9F29A33390>
# -1

# %%
print(locations)
# Out:
# [(56, 165, 146, 76)]

# %%
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data,exposure
import cv2

# %%
image = cv2.imread('virat.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
fd , hog_image = hog(image,orientations=8,pixels_per_cell=(16,16),cells_per_block=(1,1),visualize=True,multichannel=True)

# %% [markdown]
# ### **APPLYING HOG**

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(8,4),sharex=True,sharey=True)
ax1.axis('off')
ax1.imshow(image,cmap=plt.cm.gray)
ax1.set_title('Input Image')
hog_image_rescaled = exposure.rescale_intensity(hog_image,in_range=(0,10))
ax2.axis('off')
ax2.imshow(hog_image_rescaled,cmap=plt.cm.gray)
ax2.set_title('Histogram of oriented gradients')
plt.show()

# %%
len(fd)
# Out:
# 2048

# %%
image.shape
# Out:
# (260, 260, 3)

# %%
import face_recognition
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
import numpy as np
import cv2
# %matplotlib inline

# %%
image = cv2.imread('friends.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)

print("Found {} face(s) in input image.".format(number_of_faces))
# Out:
# Found 1 face(s) in input image.

# %%
image_1 = cv2.imread('virat_dhoni.jpeg')
image_1 = cv2.cvtColor(image_1,cv2.COLOR_BGR2RGB)
plt.imshow(image_1)

# %%
face_locations_multiple = face_recognition.face_locations(image_1)

numbers_of_faces = len(face_locations_multiple)

print("Found {} face(s) in input image.".format(numbers_of_faces))
# Out:
# Found 2 face(s) in input image.

# %%
multiple_image = cv2.imread('virat_dhoni.jpeg')
cv2.imwrite('virat_dhoni.jpeg', multiple_image)
# Out:
# True

# %%
cv2_imshow(multiple_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x448 at 0x7F9F29029AC8>
# -1

# %%
locations=fr.face_locations(multiple_image)
for face in locations:
	  cv2.rectangle(multiple_image,(face[3],face[0]),(face[1],face[2]),(0,255,0),2)

# %%
cv2_imshow(multiple_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=800x448 at 0x7F9F29038BA8>
# -1

# %% [markdown]
# # **FACE RECOGNITION**

# %%
import face_recognition
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
import numpy as np
# %matplotlib inline

# %%
#virat kohli
face_image = cv2.imread('virat.jpg')
virat = cv2.cvtColor(face_image,cv2.COLOR_BGR2RGB)

#mahendra singh dhoni
face_image = cv2.imread('dhoni.png')
dhoni = cv2.cvtColor(face_image,cv2.COLOR_BGR2RGB)

# %%
virat_face_recognition=face_recognition.face_encodings(virat)[0]

dhoni_face_recognition=face_recognition.face_encodings(dhoni)[0]

known_face_encodings=[virat_face_recognition,dhoni_face_recognition]

# %%
face_image = cv2.imread('virat_dhoni.jpeg')

# %%
unknown_image = cv2.cvtColor(face_image,cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings=face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
  results=[]
  for known_face_encoding in known_face_encodings:
    d= distance.euclidean(known_face_encoding,unknown_face_encoding)
    results.append(d)
  threshold = 0.6
  results = np.array(results) <= threshold

  name = "Unknown"

  if results[0]:
    name = "virat kohli"
  elif results[1]:
    name = "Mahendra Singh Dhoni"

  print(f"Found {name} in the photo!")
# Out:
# Found Mahendra Singh Dhoni in the photo!
# Found virat kohli in the photo!

# %%
face_image = cv2.imread('rohit.png')

# %%
unknown_image = cv2.cvtColor(face_image,cv2.COLOR_BGR2RGB)
plt.imshow(unknown_image)

unknown_face_encodings=face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
  results=[]
  for known_face_encoding in known_face_encodings:
    d= distance.euclidean(known_face_encoding,unknown_face_encoding)
    results.append(d)
  threshold = 0.6
  results = np.array(results) <= threshold

  name = "Unknown"

  if results[0]:
    name = "virat kohli"
  elif results[1]:
    name = "Mahendra Singh Dhoni"

  print(f"Found {name} in the photo!")
# Out:
# Found Unknown in the photo!

# %%
cv2_imshow(multiple_image)
cv2.waitKey(0)
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
  results=[]
  for known_face_encoding in known_face_encodings:
    d= distance.euclidean(known_face_encoding,unknown_face_encoding)
    results.append(d)
  threshold = 0.6
  results = np.array(results) <= threshold

  name = "Unknown"

  if results[0]:
    name = "virat kohli"
  elif results[1]:
    name = "Mahendra Singh Dhoni"

  print(f"Found {name} in the photo!")
# Out:
# <PIL.Image.Image image mode=RGB size=800x448 at 0x7F9F499D9828>
# Found Mahendra Singh Dhoni in the photo!
# Found virat kohli in the photo!
